# %% [markdown]
# # Exercise 2.A Using built-in functions

# %% [markdown]
# ## Lab 1. Working with names – parsing strings

# %%
test_name = 'John Doe'

# %%
def parse_and_display(name): 
    for i in range(len(name)): 
        if name[i] == ' ': 
            first = name[:i] 
            last = name[i+1:] 
            print(f"Full name: {name}") 
            print(f"First name: {first}") 
            print(f"Last name: {last}")

# %%
parse_and_display(test_name)
# Out:
# Full name: John Doe
# First name: John
# Last name: Doe

# %%
test_list = ['Grace Flores', 'JB Oinonen', 'Ken Penn']

# %%
parse_and_display(test_list[0])
# Out:
# Full name: Grace Flores
# First name: Grace
# Last name: Flores

# %%
parse_and_display('Jordan Worrobah')
# Out:
# Full name: Jordan Worrobah
# First name: Jordan
# Last name: Worrobah

# %%
def parse_and_display2(name):
    parts = name.split()

    print(f"Full name: {name}")

    if len(parts) == 1:
        print(f"First name: {parts[0]}")
        print("Last name: <Uknown>")

    elif len(parts) == 2:
        print(f"First name: {parts[0]}")
        print(f"Last name: {parts[1]}")

    elif len(parts) == 3:
        print(f"First name: {parts[0]}")
        print(f"Middle name: {parts[1]}")
        print(f"Last name: {parts[2]}")

# %%
parse_and_display2("Lorde")
print()

parse_and_display2("Billie Eilish")
print()

parse_and_display2("Megan Thee Stallion")
print()

parse_and_display2("Jordan Worrobah")
# Out:
# Full name: Lorde
# First name: Lorde
# Last name: <Uknown>
#
# Full name: Billie Eilish
# First name: Billie
# Last name: Eilish
#
# Full name: Megan Thee Stallion
# First name: Megan
# Middle name: Thee
# Last name: Stallion
#
# Full name: Jordan Worrobah
# First name: Jordan
# Last name: Worrobah
