# %% [markdown]
# # Capstone 2: Business Analysis with Python
#
# ## Project Overview
#
# This project analyzes sales and customer activity for EmporiUm, a fictional bookstore and retail chain. The goal of this project is to compare sales performance between two cross-region sales territories using Python data analysis tools.
#
# The territories analyzed in this project are:
#
# - Colorado — Managed by Jim Heck (West Region)
# - Florida — Managed by Lana Ilana (South Region)
#
# Using Pandas, NumPy, and Matplotlib, this analysis explores:
# - monthly sales revenue
# - store performance
# - top customers
# - product category trends
# - marketing opportunities
# - business recommendations
#
# This project was completed as part of the Year Up United Data Analytics Training Academy Python Capstone.

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Data

# %%
store_sales = pd.read_csv("StoreSales.csv")
store_sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 335129 entries, 0 to 335128
# Data columns (total 5 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Transaction Date  335129 non-null  str
#  1   Store ID          335129 non-null  int64
#  2   RewardsID         34943 non-null   float64
#  3   Prod Num          335129 non-null  str
#  4   Sale Amount       335129 non-null  float64
# dtypes: float64(2), int64(1), str(2)
# memory usage: 12.8 MB

# %%
store_detail = pd.read_csv("StoreDetail.csv")
store_detail.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 111 entries, 0 to 110
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Store Location     111 non-null    str
#  1   State              111 non-null    str
#  2   Store ID           111 non-null    int64
#  3   Territory Manager  111 non-null    str
#  4   Region             111 non-null    str
#  5   Region Director    111 non-null    str
# dtypes: int64(1), str(5)
# memory usage: 5.3 KB

# %%
products = pd.read_csv("Products.csv")
products.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 669 entries, 0 to 668
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Prod Num       669 non-null    str
#  1   Product        669 non-null    str
#  2   CategoryID     669 non-null    int64
#  3   SubcategoryID  669 non-null    str
# dtypes: int64(1), str(3)
# memory usage: 21.0 KB

# %%
product_categories = pd.read_csv("ProductCategories.csv")
product_categories.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CategoryID     52 non-null     int64
#  1   Category       52 non-null     str
#  2   SubcategoryID  52 non-null     str
#  3   Subcategory    52 non-null     str
# dtypes: int64(1), str(3)
# memory usage: 1.8 KB

# %%
customers = pd.read_csv("customer_list.csv", sep='|')
customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 521 entries, 0 to 520
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cust_id       521 non-null    int64
#  1   date          521 non-null    str
#  2   time          521 non-null    str
#  3   name          521 non-null    str
#  4   email         521 non-null    str
#  5   phone         520 non-null    str
#  6   sms-opt-out   520 non-null    str
# dtypes: int64(1), str(6)
# memory usage: 28.6 KB

# %% [markdown]
# ## Preview DataFrames

# %%
store_sales.head()
# Out:
#   Transaction Date  Store ID  RewardsID  Prod Num  Sale Amount
# 0         1/1/2022       702        NaN  105349-M         8.00
# 1         1/1/2022       704        NaN  105350-T       144.00
# 2         1/1/2022       705        NaN  105351-M        44.00
# 3         1/1/2022       705        NaN  105352-M        47.61
# 4         1/1/2022       705        NaN  105353-A        20.36

# %%
store_detail.head()
# Out:
#   Store Location     State  Store ID Territory Manager Region  Region Director
# 0         Aurora  Colorado       701          Jim Heck   West  Cassie Chambers
# 1       Berthoud  Colorado       702          Jim Heck   West  Cassie Chambers
# 2        Boulder  Colorado       703          Jim Heck   West  Cassie Chambers
# 3    Castle Rock  Colorado       704          Jim Heck   West  Cassie Chambers
# 4         Denver  Colorado       705          Jim Heck   West  Cassie Chambers

# %%
products.head()
# Out:
#     Prod Num                        Product  CategoryID SubcategoryID
# 0  105248-IT               TCL NXTPAPER 10s         120       120-tab
# 1  105249-IT  Dell Latitude 7320 Detachable         120       120-tab
# 2  105250-IT                     Realme Pad         120       120-tab
# 3  105251-IT             Lenovo Tab P12 Pro         120       120-tab
# 4  105252-IT        Microsoft Surface Pro 9         120       120-tab

# %%
product_categories.head()
# Out:
#    CategoryID                  Category SubcategoryID           Subcategory
# 0         120  Technology & Accessories       120-tab               Tablets
# 1         120  Technology & Accessories       120-cal           Calculators
# 2         120  Technology & Accessories       120-sof     Software Download
# 3         120  Technology & Accessories       120-hea            Headphones
# 4         120  Technology & Accessories       120-ext  External Accessories

# %%
customers.head()
# Out:
#    cust_id        date      time           name  \
# 0        1  2023-03-15  08:45:12         Rachel
# 1        2  2023-05-22  12:30:45      R. Geller
# 2        3  2023-07-09  18:15:27  Monica Geller
# 3        4  2023-09-01  21:05:33  Chandler Bing
# 4        5  2023-11-18  14:22:10           Joey
#
#                             email         phone sms-opt-out
# 0       rachel@centralperk.coffee  212-555-1001            N
# 1        rossg@centralperk.coffee  212-555-1002            N
# 2   chefmonica@centralperk.coffee  212-555-1003            N
# 3    chandlerb@centralperk.coffee  212-555-1004            Y
# 4  howyoudoing@centralperk.coffee  212-555-1005            N

# %% [markdown]
# ## Checking each dataset columns

# %%
store_sales.columns
# Out:
# Index(['Transaction Date', 'Store ID', 'RewardsID', 'Prod Num', 'Sale Amount'], dtype='str')

# %%
store_detail.columns
# Out:
# Index(['Store Location', 'State', 'Store ID', 'Territory Manager', 'Region',
#        'Region Director'],
#       dtype='str')

# %%
products.columns
# Out:
# Index(['Prod Num', 'Product', 'CategoryID', 'SubcategoryID'], dtype='str')

# %%
product_categories.columns
# Out:
# Index(['CategoryID', 'Category', 'SubcategoryID', 'Subcategory'], dtype='str')

# %%
customers.columns
# Out:
# Index(['cust_id', 'date', 'time', 'name', 'email', 'phone', 'sms-opt-out '], dtype='str')

# %% [markdown]
# ## Data Cleaning

# %%
customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 521 entries, 0 to 520
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cust_id       521 non-null    int64
#  1   date          521 non-null    datetime64[us]
#  2   time          521 non-null    str
#  3   name          521 non-null    str
#  4   email         521 non-null    str
#  5   phone         520 non-null    str
#  6   sms-opt-out   520 non-null    str
# dtypes: datetime64[us](1), int64(1), str(5)
# memory usage: 28.6 KB

# %%
customers.isnull().sum()
# Out:
# cust_id         0
# date            0
# time            0
# name            0
# email           0
# phone           1
# sms-opt-out     1
# dtype: int64

# %%
customers["date"] = pd.to_datetime(customers["date"])

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
customers = customers.drop_duplicates()

# %%
customers.head()
# Out:
#    cust_id       date      time           name  \
# 0        1 2023-03-15  08:45:12         Rachel
# 1        2 2023-05-22  12:30:45      R. Geller
# 2        3 2023-07-09  18:15:27  Monica Geller
# 3        4 2023-09-01  21:05:33  Chandler Bing
# 4        5 2023-11-18  14:22:10           Joey
#
#                             email         phone sms-opt-out
# 0       rachel@centralperk.coffee  212-555-1001            N
# 1        rossg@centralperk.coffee  212-555-1002            N
# 2   chefmonica@centralperk.coffee  212-555-1003            N
# 3    chandlerb@centralperk.coffee  212-555-1004            Y
# 4  howyoudoing@centralperk.coffee  212-555-1005            N

# %% [markdown]
# The customer list was separated using this "|" , so I used sep="|" to keep formatting consitent. Also, I changed the customer signup date column to datetime and checked for missing values and duplicates.

# %% [markdown]
# ## Core Marketing Analysis

# %% [markdown]
# Who are the territory managers for the sales territories assigned?
#
# What are the store IDs and cities for the stores in each assigned sales territory?

# %%
colorado_stores = store_detail[store_detail["State"] == "Colorado"]

# %%
display(colorado_stores[["Store ID", "Store Location", "Territory Manager"]])
# Out:
#     Store ID  Store Location Territory Manager
# 0        701          Aurora          Jim Heck
# 1        702        Berthoud          Jim Heck
# 2        703         Boulder          Jim Heck
# 3        704     Castle Rock          Jim Heck
# 4        705          Denver          Jim Heck
# 5        706       Englewood          Jim Heck
# 6        707    Fort Collins          Jim Heck
# 7        708  Grand Junction          Jim Heck
# 8        709         Greeley          Jim Heck
# 9        710       Lafayette          Jim Heck
# 10       711       Littleton          Jim Heck
# 11       712        Loveland          Jim Heck
# 12       713        Milliken          Jim Heck
# 13       714      New Castle          Jim Heck
# 14       715          Parker          Jim Heck
# 15       716         Sedalia          Jim Heck
# 16       717        Thornton          Jim Heck
# 17       718     Wheat Ridge          Jim Heck

# %%
florida_stores = store_detail[store_detail["State"] == "Florida"]

# %%
display(florida_stores[["Store ID", "Store Location", "Territory Manager"]])
# Out:
#     Store ID   Store Location Territory Manager
# 26       719   Cape Canaveral        Lana Ilana
# 27       720  Fort Lauderdale        Lana Ilana
# 28       721     Jacksonville        Lana Ilana
# 29       722         Key West        Lana Ilana
# 30       723         Lakeland        Lana Ilana
# 31       724            Miami        Lana Ilana
# 32       725           Naples        Lana Ilana
# 33       726          Orlando        Lana Ilana
# 34       727          Sebring        Lana Ilana
# 35       728      Tallahassee        Lana Ilana
# 36       729            Tampa        Lana Ilana

# %% [markdown]
# ### Territory Overview Findings
#
# The Colorado territory is managed by Jim Heck which is the West region, while the Florida territory is managed by Lana Ilana which is the South region.
#
# Both territories contain multiple store locations distributed across different cities. Because these territories belong to different regions of the country, they may show differences in customer behavior, product demand, and revenue trends.
